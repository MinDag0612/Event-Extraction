# %%
uv run bash data/raw/MAVEN-Arg/download.sh
# Out:
# Note: you may need to restart the kernel to use updated packages.
# d:\EVENT EXTRACTION\sourse\.venv\Scripts\python.exe: No module named uv

# %%
from pathlib import Path
import sys

ROOT = Path.cwd().parents[1]

sys.path.insert(0, str(ROOT))

print(ROOT)
# Out:
# d:\EVENT EXTRACTION\sourse

# %%
from src.adapter.MAVEN_adapter import MAVENAdapter
import json

# %%
with open(ROOT/"data/raw/MAVEN-Arg/train.jsonl", "r", encoding="utf-8") as file:
    data = json.loads(next(file))

adapted_data = MAVENAdapter().adapt(data)
display(adapted_data.events[0].arguments)
# Out:
# [Argument(role='Agent', mentions=[{'text': 'a corps of volunteers led by giuseppe garibaldi', 'span': [137, 184]}]),
#  Argument(role='Location_original', mentions=[{'text': 'quarto', 'span': [197, 203]}, {'text': 'quarto dei mille', 'span': [223, 239]}]),
#  Argument(role='Location_final', mentions=[{'text': 'marsala', 'span': [256, 263]}])]

# %%
from src.unified_format.adapter_inspector import AdapterInspector

inspector = AdapterInspector(MAVENAdapter(), "MAVEN-Arg")
inspector.inspect_sample(index=0)
# Out:
# Dataset: MAVEN-Arg
# Sample: 0
#
# RAW
# ├── id: "364ed14fc610df6e25a2f446e2b2d2ab"
# ├── title: "Expedition of the Thousand"
# ├── document: "The Expedition of the Thousand ( Italian `` Spedizione dei Mille '' ) was an event of the Italian Risorgimento that took place in 1860 . a corps of volunteers led by giuseppe garibaldi sailed from quarto , near genoa ( now quarto dei mille ) and landed in marsala , sicily , in order to conquer the kingdom of the two sicilies , ruled by the house of bourbon-two sicilies . The project was an ambitious and risky venture aiming to conquer , with a thousand men , a kingdom with a larger regular army and a more powerful navy . The expedition was a success and concluded with a plebiscite that brought Naples and Sicily into the Kingdom of Sardinia , the last territorial conquest before the creation of the Kingdom of Italy on 17 March 1861 . The sea venture was the only desired action that was jointly decided by the `` four fathers of the nation '' Giuseppe Mazzini , Giuseppe Garibaldi , Victor Emmanuel II , and Camillo Cavour , pursuing divergent goals . However , the Expedition was instigated by Francesco Crispi , who utilized his political influence to bolster the Italian unification project . The various groups participated in the expedition for a variety of reasons : for Garibaldi , it was to achieve a united Italy ; to the Sicilian bourgeoisie , an independent Sicily as part of the kingdom of Italy , and for common people , land distribution and the end of oppression ."
# ├── events: [{"id": "EVENT_f535eb21f8f958a04cbc69c1d1521186", "type": "Motion", "type_id": 46, "mention": [{"id": "ba52b07af376a19bff47136177244b96", "trigger_word": "Expedition", "offset": [4, 14]}, {"id": "e52fe3ae0d43ed54c49d5980771c1a8a", "trigger_word": "venture", "offset": [413, 420]}, {"id": "f89b405432358e6de5ad252c2c8d38d8", "trigger_word": "expedition", "offset": [531, 541]}, {"id": "cd02764a98a51fb3ec943f7807dbe24d", "trigger_word": "Expedition", "offset": [975, 985]}, {"id": "e3d0b625f8d6c3f0e8a80671e9a0455c", "trigger_word": "expedition", "offset": [1144, 1154]}], "argument": {"Agent": [{"content": "a corps of volunteers led by giuseppe garibaldi", "offset": [137, 184]}], "Location_original": [{"entity_id": "ENTITY_052c8614c4bb87b5321807d1980332f6"}], "Location_final": [{"entity_id": "ENTITY_185734cbbe4da16fb0782dfaa326529c"}]}}, {"id": "EVENT_451b7cde13d2b8c21426db027c51096f", "type": "Motion", "type_id": 46, "mention": [{"id": "1c6807377cd111b86d2d3afc85bf2ca2", "trigger_word": "sailed", "offset": [185, 191]}], "argument": {"Agent": [{"content": "a corps of volunteers led by giuseppe garibaldi", "offset": [137, 184]}], "Location_original": [{"entity_id": "ENTITY_052c8614c4bb87b5321807d1980332f6"}], "Location_final": [{"entity_id": "ENTITY_185734cbbe4da16fb0782dfaa326529c"}]}}, {"id": "EVENT_5d5130ba19c9706c4fff53d34225fb1c", "type": "Process_start", "type_id": 31, "mention": [{"id": "da9ce84d31424b80e1e511cb8ede7c91", "trigger_word": "took place", "offset": [116, 126]}], "argument": {"Agent": [{"entity_id": "ENTITY_69a502f107a35dd7554539f07fd0c4d1"}], "Patient": [{"content": "Expedition of the Thousand", "offset": [4, 30]}], "Location": [{"entity_id": "ENTITY_052c8614c4bb87b5321807d1980332f6"}, {"entity_id": "ENTITY_185734cbbe4da16fb0782dfaa326529c"}], "Symbol": [], "Purpose": [{"content": "conquer the kingdom of the two sicilies , ruled by the house of bourbon-two sicilies", "offset": [287, 371]}]}}, {"id": "EVENT_d2587256a67ce75ea9d9d864288d822c", "type": "Motion", "type_id": 10, "mention": [{"id": "187955a9227516bae5cf7198e30a3cd4", "trigger_word": "landed", "offset": [246, 252]}], "argument": {"Agent": [{"content": "a corps of volunteers led by giuseppe garibaldi", "offset": [137, 184]}], "Location_original": [{"entity_id": "ENTITY_052c8614c4bb87b5321807d1980332f6"}], "Location_final": [{"entity_id": "ENTITY_185734cbbe4da16fb0782dfaa326529c"}]}}, {"id": "EVENT_e71684bf9f6e7b50bf5316982a640c15", "type": "Creating", "type_id": 60, "mention": [{"id": "ee662538dab38ae06acd111c81cd5604", "trigger_word": "creation", "offset": [691, 699]}], "argument": {"Creator": [], "Patient": [{"entity_id": "ENTITY_c8493fe1fe272239bf20812f2e71e238"}], "Location": [{"content": "Italy", "offset": [718, 723]}], "Purpose": []}}, {"id": "EVENT_c027e659d7fe424a0a57ecbe35b3a7f9", "type": "Conquering", "type_id": 21, "mention": [{"id": "cfd1fa5450f7f4a3ce3d6ae48ca642d3", "trigger_word": "conquer", "offset": [287, 294]}, {"id": "43dcdddc70f53e61ed7afeeeb91b6c48", "trigger_word": "conquer", "offset": [431, 438]}, {"id": "1135d9ecf33c68ac7c21d816ac1871d4", "trigger_word": "conquest", "offset": [671, 679]}], "argument": {"Agent": [{"content": "a corps of volunteers led by giuseppe garibaldi", "offset": [137, 184]}], "Patient": [{"entity_id": "ENTITY_18e78f09fb967fa6a8ac1e527a782b90"}], "Location": [{"entity_id": "ENTITY_185734cbbe4da16fb0782dfaa326529c"}], "Name": [{
a695ec530b7114f94f7", "trigger_word": "success", "offset": [548, 555]}, {"id": "ba1848d266b115fffc9cbe8bcd04408e", "trigger_word": "Naples", "offset": [601, 607]}, {"id": "49a0bf264ab72e780c2a5af55f62847e", "trigger_word": "Sicily", "offset": [612, 618]}, {"id": "ddd0175054779de5c179e1b399501252", "trigger_word": "Kingdom", "offset": [628, 635]}, {"id": "6610f4d18dcaee2da2719d9e34ddebcc", "trigger_word": "Sardinia", "offset": [639, 647]}, {"id" ...
#
# ADAPTED
# ├── id: '364ed14fc610df6e25a2f446e2b2d2ab'
# ├── text: "The Expedition of the Thousand ( Italian `` Spedizione dei Mille '' ) was an event of the Italian Risorgimento that took place in 1860 . a corps of volunteers led by giuseppe garibaldi sailed from quarto , near genoa ( now quarto dei mille ) and landed in marsala , sicily , in order to conquer the kingdom of the two sicilies , ruled by the house of bourbon-two sicilies . The project was an ambitious and risky venture aiming to conquer , with a thousand men , a kingdom with a larger regular army and a more powerful navy . The expedition was a success and concluded with a plebiscite that brought Naples and Sicily into the Kingdom of Sardinia , the last territorial conquest before the creation of the Kingdom of Italy on 17 March 1861 . The sea venture was the only desired action that was jointly decided by the `` four fathers of the nation '' Giuseppe Mazzini , Giuseppe Garibaldi , Victor Emmanuel II , and Camillo Cavour , pursuing divergent goals . However , the Expedition was instigated by Francesco Crispi , who utilized his political influence to bolster the Italian unification project . The various groups participated in the expedition for a variety of reasons : for Garibaldi , it was to achieve a united Italy ; to the Sicilian bourgeoisie , an independent Sicily as part of the kingdom of Italy , and for common people , land distribution and the end of oppression ."
# └── events
#     ├── Event[0]
#     │   ├── event_type: None
#     │   ├── trigger: Trigger(text=None, span=None)
#     │   └── arguments
#     │       ├── Agent: [{"text": "a corps of volunteers led by giuseppe garibaldi", "span": [137, 184]}]
#     │       ├── Location_original: [{"text": "quarto", "span": [197, 203]}, {"text": "quarto dei mille", "span": [223, 239]}]
#     │       └── Location_final: [{"text": "marsala", "span": [256, 263]}]
#     ├── Event[1]
#     │   ├── event_type: None
#     │   ├── trigger: Trigger(text=None, span=None)
#     │   └── arguments
#     │       ├── Agent: [{"text": "a corps of volunteers led by giuseppe garibaldi", "span": [137, 184]}]
#     │       ├── Location_original: [{"text": "quarto", "span": [197, 203]}, {"text": "quarto dei mille", "span": [223, 239]}]
#     │       └── Location_final: [{"text": "marsala", "span": [256, 263]}]
#     ├── Event[2]
#     │   ├── event_type: None
#     │   ├── trigger: Trigger(text=None, span=None)
#     │   └── arguments
#     │       ├── Agent: [{"text": "Garibaldi", "span": [1186, 1195]}, {"text": "Giuseppe Garibaldi", "span": [871, 889]}, {"text": "giuseppe garibaldi", "span": [166, 184]}]
#     │       ├── Patient: [{"text": "Expedition of the Thousand", "span": [4, 30]}]
#     │       ├── Location: [{"text": "quarto", "span": [197, 203]}, {"text": "quarto dei mille", "span": [223, 239]}, {"text": "marsala", "span": [256, 263]}]
#     │       ├── Symbol: []
#     │       └── Purpose: [{"text": "conquer the kingdom of the two sicilies , ruled by the house of bourbon-two sicilies", "span": [287, 371]}]
#     ├── Event[3]
#     │   ├── event_type: None
#     │   ├── trigger: Trigger(text=None, span=None)
#     │   └── arguments
#     │       ├── Agent: [{"text": "a corps of volunteers led by giuseppe garibaldi", "span": [137, 184]}]
#     │       ├── Location_original: [{"text": "quarto", "span": [197, 203]}, {"text": "quarto dei mille", "span": [223, 239]}]
#     │       └── Location_final: [{"text": "marsala", "span": [256, 263]}]
#     ├── Event[4]
#     │   ├── event_type: None
#     │   ├── trigger: Trigger(text=None, span=None)
#     │   └── arguments
#     │       ├── Creator: []
#     │       ├── Patient: [{"text": "Kingdom of Italy", "span": [707, 723]}, {"text": "kingdom of Italy", "span": [1300, 1316]}, {"text": "Italian", "span": [90, 97]}, {"text": "Italy", "span": [1225, 1230]}, {"text": "Italian", "span": [1075, 1082]}]
#     │       ├── Location: [{"text": "Italy", "span": [718, 723]}]
#     │       └── Purpose: []
#     ├── Event[5]
#     │   ├── event_type: None
#     │   ├── trigger: Trigger(text=None, span=None)
#     │   └── arguments
#     │       ├── Agent: [{"text": "a corps of volunteers led by giuseppe garibaldi", "span": [137, 184]}]
#     │       ├── Patient: [{"text": "kingdom of the two sicilies", "span": [299, 326]}]
#     │       ├── Location: [{"text": "marsala", "span": [256, 263]}]
#     │       └── Name: [{"text": "Expedition of the Thousand", "span": [4, 30]}]
#     ├── Event[6]
#     │   ├── event_type: None
#     │   ├── trigger: Trigger(text=None, span=None)
#     │   └── arguments
#     │       ├── Agent: [{"text": "a corps of volunteers led by giuseppe garibaldi", "span": [137, 184]}]
#     │       ├── Patient: [{"text": "Expedition of the Thousand", "span": [4, 30]}]
#     │       ├── Symbol_event: [{"text": "a plebiscite", "span": [575, 587]}]
#     │       └── Location: [{"text": "marsala", "span": [256, 263]}]
#     ├── Event[7]
#     │   ├── event_type: None
#     │   ├── trigger: Trigger(text=None, span=None)
#     │   └── arguments
#     │       ├── Agent: []
#     │       ├── Content: [{"text": "brought Naples and Sicily into the Kingdom of Sardinia", "span": [593, 647]}]
#     │       ├── Location: [{"text": "Naples", "span": [601, 607]}, {"text": "Sicily", "span": [612, 618]}]
#     │       ├── Purpose: []
#     │       └── Outcome: []
#     ├── Event[8]
#     │   ├── event_type: None
#     │   ├── trigger: Trigger(text=None, span=None)
#     │   └── arguments
#     │       ├── Agent: [{"text": "house of bourbon-two sicilies", "span": [342, 371]}]
#     │       ├── Patient: [{"text": "kingdom of the two sicilies", "span": [299, 326]}]
#     │       └── Method: []
#     ├── Event[9]
#     │   ├── event_type: None
#     │   ├── trigger: Trigger(text=None, span=None)
#     │   └── arguments
#     │       ├── Agent: []
#     │       ├── Patient: [{"text": "Naples", "span": [601, 607]}, {"text": "Sicily", "span": [612, 618]}]
#     │       └── Destination: [{"text": "Kingdom of Sardinia", "span": [628, 647]}]
#     ├── Event[10]
#     │   ├── event_type: None
#     │   ├── trigger: Trigger(text=None, span=None)
#     │   └── arguments
#     │       ├── Agent: [{"text": "a corps of volunteers led by giuseppe garibaldi", "span": [137, 184]}]
#     │       ├── Activity: [{"text": "The project", "span": [374, 385]}]
#     │       ├── Location: [{"text": "marsala", "span": [256, 263]}]
#     │       └── Target_Objective: [{"text": "conquer , with a thousand men , a kingdom with a larger regular army and a more powerful navy", "span": [431, 524]}]
#     ├── Event[11]
#     │   ├── event_type: None
#     │   ├── trigger: Trigger(text=None, span=None)
#     │   └── arguments
#     │       ├── Agent: [{"text": "Francesco Crispi", "span": [1004, 1020]}, {"text": "who", "span": [1023, 1026]}]
#     │       ├── Patient: [{"text": "his political influence", "span": [1036, 1059]}]
#     │       ├── Location: [{"text": "Italy", "span": [718, 723]}]
#     │       ├── Purpose: [{"text": "bolster the Italian unification project", "span": [1063, 1102]}]
#     │       └── Outcome: []
#     ├── Event[12]
#     │   ├── event_type: None
#     │   ├── trigger: Trigger(text=None, span=None)
#     │   └── arguments
#     │       ├── Agent: [{"text": "Giuseppe Mazzini", "span": [852, 868]}, {"text": "Garibaldi", "span": [1186, 1195]}, {"text": "Giuseppe Garibaldi", "span": [871, 889]}, {"text": "giuseppe garibaldi", "span": [166, 184]}, {"text": "Victor Emmanuel II", "span": [892, 910]}, {"text": "Camillo Cavour", "span": [917, 931]}]
#     │       ├── Location: [{"text": "Italy", "span": [718, 723]}]
#     │       ├── Content: [{"text": "The sea venture", "span": [743, 758]}]
#     │       ├── Instrument: []
#     │       ├── Purpose: [{"text": "pursuing divergent goals", "span": [934, 958]}]
#     │       ├── Outcome: []
#     │       └── Motivation: []
#     ├── Event[13]
#     │   ├── event_type: None
#     │   ├── trigger: Trigger(text=None, span=None)
#     │   └── arguments
#     │       ├── Agent: [{"text": "Francesco Crispi", "span": [1004, 1020]}, {"text": "who", "span": [1023, 1026]}]
#     │       ├── Patient: [{"text": "the Italian unification project", "span": [1071, 1102]}]
#     │       ├── State: []
#     │       ├── Method: []
#     │       ├── Location: [{"text": "Italy", "span": [718, 723]}]
#     │       └── Purpose: []
#     ├── Event[14]
#     │   ├── event_type: None
#     │   ├── trigger: Trigger(text=None, span=None)
#     │   └── arguments
#     │       ├── Agent: [{"text": "Giuseppe Mazzini", "span": [852, 868]}, {"text": "Garibaldi", "span": [1186, 1195]}, {"text": "Giuseppe Garibaldi", "span": [871, 889]}, {"text": "giuseppe garibaldi", "span": [166, 184]}, {"text": "Victor Emmanuel II", "span": [892, 910]}, {"text": "Camillo Cavour", "span": [917, 931]}]
#     │       ├── Location_original: []
#     │       └── Location_final: []
#     ├── Event[15]
#     │   ├── event_type: None
#     │   ├── trigger: Trigger(text=None, span=None)
#     │   └── arguments
#     │       ├── Agent: [{"text": "Francesco Crispi", "span": [1004, 1020]}, {"text": "who", "span": [1023, 1026]}]
#     │       ├── Patient: [{"text": "the Expedition", "span": [971, 985]}]
#     │       ├── Location: [{"text": "Italy", "span": [718, 723]}]
#     │       ├── Symbol: []
#     │       └── Purpose: []
#     ├── Event[16]
#     │   ├── event_type: None
#     │   ├── trigger: Trigger(text=None, span=None)
#     │   └── arguments
#     │       ├── Agent: []
#     │       ├── Participants: []
#     │       ├── Group: []
#     │       └── Result: [{"text": "Kingdom of Italy", "span": [707, 723]}, {"text": "kingdom of Italy", "span": [1300, 1316]}, {"text": "Italian", "span": [90, 97]}, {"text": "Italy", "span": [1225, 1230]}, {"text": "Italian", "span": [1075, 1082]}]
#     ├── Event[17]
#     │   ├── event_type: None
#     │   ├── trigger: Trigger(text=None, span=None)
#     │   └── arguments
#     │       ├── Agent: []
#     │       ├── Patient: [{"text": "oppression", "span": [1376, 1386]}]
#     │       ├── Symbol_event: []
#     │       └── Location: [{"text": "Italy", "span": [718, 723]}]
#     ├── Event[18]
#     │   ├── event_type: None
#     │   ├── trigger: Trigger(text=None, span=None)
#     │   └── arguments
#     │       ├── Participant: [{"text": "Garibaldi", "span": [1186, 1195]}, {"text": "Giuseppe Garibaldi", "span": [871, 889]}, {"text": "giuseppe garibaldi", "span": [166, 184]}, {"text": "sicily", "span": [266, 272]}, {"text": "Sicily", "span": [1278, 1284]}, {"text": "Sicilian", "span": [1240, 1248]}, {"text": "Sicily", "span": [612, 618]}, {"text": "common people", "span": [1327, 1340]}]
#     │       ├── Patient: []
#     │       ├── Location: [{"text": "quarto", "span": [197, 203]}, {"text": "quarto dei mille", "span": [223, 239]}, {"text": "marsala", "span": [256, 263]}]
#     │       └── Purpose: [{"text": "achieve a united Italy", "span": [1208, 1230]}, {"text": "an independent Sicily as part of the kingdom of Italy", "span": [1263, 1316]}, {"text": "land distribution", "span": [1343, 1360]}, {"text": "end of oppression", "span": [1369, 1386]}]
#     ├── Event[19]
#     │   ├── event_type: None
#     │   ├── trigger: Trigger(text=None, span=None)
#     │   └── arguments
#     │       ├── Agent: [{"text": "land", "span": [1343, 1347]}]
#     │       ├── Location_begin: []
#     │       └── Location_end: []
#     └── Event[20]
#         ├── event_type: None
#         ├── trigger: Trigger(text=None, span=None)
#         └── arguments
#             ├── Agent: [{"text": "Garibaldi", "span": [1186, 1195]}, {"text": "Giuseppe Garibaldi", "span": [871, 889]}, {"text": "giuseppe garibaldi", "span": [166, 184]}]
#             └── Goal: [{"text": "a united Italy", "span": [1216, 1230]}]
