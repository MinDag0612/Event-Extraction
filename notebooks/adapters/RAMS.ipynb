# %%
from pathlib import Path
import sys
import json

ROOT = Path.cwd().parents[1]
sys.path.insert(0, str(ROOT))

# %%
from src.adapter.RAMS_adapter import RAMSAdapter

# %%
with open(ROOT/"data/raw/RAMS/train.jsonlines", "r", encoding="utf-8") as file:
    data = json.loads(next(file))

data

# %%
adapter = RAMSAdapter()
sample = adapter.adapt(data)

print(json.dumps(json.loads(sample.to_json()), ensure_ascii=False, indent=2))
